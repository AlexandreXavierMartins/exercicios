# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexandreXavierMartins/exercicios/blob/main/Plot_Delta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt


x = []
y = []


x.append(0.0001)
y.append(np.exp(-1/0.0001))
for i in range(1, 50):
  x.append(i)
  y.append(np.exp(-1/i))

plt.plot(x, y)
plt.title("Probabilidade X Temperatura", fontsize = 15, fontweight = 'bold')
plt.xlabel("Temperatura", fontsize = 12, fontweight = 'bold')
plt.ylabel("Probabilidade", fontsize = 12, fontweight = 'bold')
plt.yticks(fontweight='bold')
plt.show()
